# %% [markdown]
# # User Info

# %%
#registration area 
import sqlite3
def registration():
    name=input("Enter Your Name:").capitalize()
    pn=input("Enter Your Phone Number:")
    print("\n"*2)
    return(name,pn)

# %% [markdown]
# # Get Pricing of Items

# %%
password="root"
# price=0
clear=False
admin={"Shrish":9846856033,"Abhishek":9827178883}
x1a="Veg Meal";x1b="Chicken Meal";x1c="Mutton Meal";
x2a="Veg MO:MO"; x2b="Chicken MO:MO"; x2c="Buff MO:MO";
x3a="Veg Chowmin"; x3b="Chicken Chowmin"; x3c="Buff Chowmin"; 
x4a="Black Tea"; x4b="Milk Tea"; x4c="Green Tea"; 
x5a="Black Coffee"; x5b="Milk Coffee"; x6a="Red Wine"; x6b="White Wine"
#aba value ko lai 
# x1av=200;x1bv=250;x1cv=300;
# x2av=100;x2bv=160;x2cv=120;
# x3av=80;x3bv=120;x3cv=100;
# x4av=40;x4bv=60;x4cv=100;
# x5av=100;x5bv=140;
# x6av=400;x6bv=500;
conn = sqlite3.connect("menu.db")
cur = conn.cursor()
#MEAL
x1av,=cur.execute("SELECT itemPrice FROM MENU_MODEL WHERE menuItem=? ",(x1a,)).fetchone()
x1bv,=cur.execute("SELECT itemPrice FROM MENU_MODEL WHERE menuItem=? ",(x1b,)).fetchone()
x1cv,=cur.execute("SELECT itemPrice FROM MENU_MODEL WHERE menuItem=? ",(x1c,)).fetchone()

#MOMO
x2av,=cur.execute("SELECT itemPrice FROM MENU_MODEL WHERE menuItem=? ",(x2a,)).fetchone()
x2bv,=cur.execute("SELECT itemPrice FROM MENU_MODEL WHERE menuItem=? ",(x2b,)).fetchone()
x2cv,=cur.execute("SELECT itemPrice FROM MENU_MODEL WHERE menuItem=? ",(x2c,)).fetchone()

#CHOWMIN
x3av,=cur.execute("SELECT itemPrice FROM MENU_MODEL WHERE menuItem=? ",(x3a,)).fetchone()
x3bv,=cur.execute("SELECT itemPrice FROM MENU_MODEL WHERE menuItem=? ",(x3b,)).fetchone()
x3cv,=cur.execute("SELECT itemPrice FROM MENU_MODEL WHERE menuItem=? ",(x3c,)).fetchone()

#TEA
x4av,=cur.execute("SELECT itemPrice FROM MENU_MODEL WHERE menuItem=? ",(x4a,)).fetchone()
x4bv,=cur.execute("SELECT itemPrice FROM MENU_MODEL WHERE menuItem=? ",(x4b,)).fetchone()
x4cv,=cur.execute("SELECT itemPrice FROM MENU_MODEL WHERE menuItem=? ",(x4c,)).fetchone()

#COFFEE
x5av,=cur.execute("SELECT itemPrice FROM MENU_MODEL WHERE menuItem=? ",(x5a,)).fetchone()
x5bv,=cur.execute("SELECT itemPrice FROM MENU_MODEL WHERE menuItem=? ",(x5b,)).fetchone()

#WINE
x6av,=cur.execute("SELECT itemPrice FROM MENU_MODEL WHERE menuItem=? ",(x6a,)).fetchone()
x6bv,=cur.execute("SELECT itemPrice FROM MENU_MODEL WHERE menuItem=? ",(x6b,)).fetchone()
conn.close()

# %% [markdown]
# # Order Section

# %%
bill=dict()
def order():
    global x1a,x1b,x1c,x2a,x2b,x2c,x3a,x3b,x3c,x4a,x4b,x4c,x5a,x5b,x6a,x6b#ItemName
    global bill#dict ma edit garna 
#     global price#global price change
    z=True
    conn=sqlite3.connect("soldDetails.db")
    cur=conn.cursor()
    print("\n"*10)
    print(f"""\t1.MEAL(VEG,CHICKEN,MUTTON)------>Rs({x1av},{x1bv},{x1cv})\n
        2.MO:MO(VEG,CHICKEN,BUFF)------->Rs({x2av},{x2bv},{x2cv})\n
        3.CHOWMIN(VEG,CHICKEN,BUFF)----->Rs({x3av},{x3bv},{x3cv})\n
        4.TEA(BLACK,MILK,GREEN)--------->Rs({x4av},{x4bv},{x4cv})\n
        5.COFFEE(BLACK,MILK)------------>Rs({x5av},{x5bv})\n
        6.WINE(RED,WHITE):PER_GLASS----->Rs({x6av},{x6bv})""")
    try:
        x=int(input("Enter Your Choice:"))
        if x not in range(1,7):
            raise
    except:
        print("\nPlease choose 1-6")
        order()
    else:
        while z:
            if x==1:
                #MEAL
                print(f"""\n-------------MEAL----------\na.Veg-------->Rs.{x1av} \nb.Chicken---->Rs.{x1bv}\nc.Mutton----->Rs.{x1cv}\n""")
                try:
                    x1=input("\nEnter  Your Choice:")
                    if x1 not in "abc":
                        raise
                except:
                    print("\nPlease Choose a ,b or c")
                    continue
                else:
                    #VEG--->200
                    if x1=="a":
                        x1ai=x1a+"-------"
                        bill[x1ai]=x1av
                        cur.execute("INSERT INTO sales (ItemName,ItemPrice,Date) VALUES (?,?,datetime('now','localtime'))",(x1a,x1av))
                        conn.commit()


                    #Chicken---> 250   
                    elif x1=="b": 
                        x1bi=x1b+"---"
                        bill[x1bi]=x1bv
                        cur.execute("INSERT INTO sales (ItemName,ItemPrice,Date) VALUES (?,?,datetime('now','localtime'))",(x1b,x1bv) )
                        conn.commit()


                    #Mutton-->300
                    elif x1=="c":
                        x1ci=x1c+"----"
                        bill[x1ci]=x1cv
                        cur.execute("INSERT INTO sales (ItemName,ItemPrice,Date) VALUES (?,?,datetime('now','localtime'))",(x1c,x1cv) )
                        conn.commit()








            elif x==2:
                #MO:MO(VEG,CHICKEN,BUFF)------->Rs(100,160,120)
                print(f"\n-------------MO:MO----------\na.Veg-------->Rs.{x2av}\nb.Chicken---->Rs.{x2bv}\nc.Buff------->Rs.{x2cv}")
                try:

                    x2=input("\nEnter  Your Choice:")
                    if x2 not in "abc":
                        raise
                except:
                    print("\nPlease Choose a ,b or c")
                    continue
                else:
                    #VEG--->100
                    if x2=="a":
                        x2ai=x2a+"------"
                        bill[x2ai]=x2av
                        cur.execute("INSERT INTO sales (ItemName,ItemPrice,Date) VALUES (?,?,datetime('now','localtime'))",(x2a,x2av) )
                        conn.commit()


                    #Chicken--->160   
                    elif x2=="b": 
                        x2bi=x2b+"--"
                        bill[x2bi]=x2bv
                        cur.execute("INSERT INTO sales (ItemName,ItemPrice,Date) VALUES (?,?,datetime('now','localtime'))",(x2b,x2bv) )
                        conn.commit()


                    #buff--->120
                    elif x2=="c":
                        x2ci=x2c+"-----"
                        bill[x2ci]=x2cv
                        cur.execute("INSERT INTO sales (ItemName,ItemPrice,Date) VALUES (?,?,datetime('now','localtime'))",(x2c,x2cv) )
                        conn.commit()









            elif x==3:
                #CHOWMIN(VEG,CHICKEN,BUFF)----->Rs(80,120,100)
                print(f"\n------------CHOWMIN----------\na.Veg-------->Rs.{x3av}\nb.Chicken---->Rs.{x3bv}\nc.Buff------->Rs.{x3cv}\n")
                try:

                    x3=input("\nEnter  Your Choice:")
                    if x3 not in "abc":
                        raise
                except:
                    print("\nPlease Choose a ,b or c")
                    continue
                else:
                    #VEG--->80
                    if x3=="a":
                        x3ai=x3a+"----"
                        bill[x3ai]=x3av
                        cur.execute("INSERT INTO sales (ItemName,ItemPrice,Date) VALUES (?,?,datetime('now','localtime'))",(x3a,x3av) )
                        conn.commit()


                    #Chicken--->120   
                    elif x3=="b": 
                        x3bi=x3b
                        bill[x3bi]=x3bv
                        cur.execute("INSERT INTO sales (ItemName,ItemPrice,Date) VALUES (?,?,datetime('now','localtime'))",(x3b,x3bv) )
                        conn.commit()


                    #buff--->100
                    elif x3=="c":
                        x3ci=x3c+"---"
                        bill[x3ci]=x3cv  
                        cur.execute("INSERT INTO sales (ItemName,ItemPrice,Date) VALUES (?,?,datetime('now','localtime'))",(x3c,x3cv) )
                        conn.commit()




            elif x==4:
                #TEA(BLACK,MILK,GREEN)--------->Rs(40,60,100)
                print(f"\n--------------TEA----------\na.Black---->Rs.{x4av}\nb.Milk----->Rs.{x4bv}\nc.Green---->Rs.{x4cv}\n")
                try:
                    x4=input("\nEnter  Your Choice:")
                    if x4 not in "abc":
                        raise
                except:
                    print("\nPlease Choose a ,b or c")
                    continue
                else:
                    #Black--->40
                    if x4=="a":
                        x4ai=x4a+"------"
                        bill[x4ai]=x4av
                        cur.execute("INSERT INTO sales (ItemName,ItemPrice,Date) VALUES (?,?,datetime('now','localtime'))",(x4a,x4av) )
                        conn.commit()


                    #milk--->60   
                    elif x4=="b": 
                        x4bi=x4b+"-------"
                        bill[x4bi]=x4bv
                        cur.execute("INSERT INTO sales (ItemName,ItemPrice,Date) VALUES (?,?,datetime('now','localtime'))",(x4b,x4bv) )
                        conn.commit()


                    #green--->100
                    elif x4=="c":
                        x4ci=x4c+"------"
                        bill[x4ci]=x4cv
                        cur.execute("INSERT INTO sales (ItemName,ItemPrice,Date) VALUES (?,?,datetime('now','localtime'))",(x4c,x4cv) )
                        conn.commit()



            elif x==5:
                #COFFEE(BLACK,MILK)------------>Rs(100,140)
                print(f"\n--------------COFFEE----------\na.Black---->Rs.{x5av}\nb.Milk----->Rs.{x5bv}\n")
                try:
                    x5=input("Enter  Your Choice:")
                    if x5 not in "ab":
                        raise
                except:
                    print("Please Choose a or b ")
                    continue
                else:
                    #Black--->100
                    if x5=="a":
                        x5ai=x5a+"---"
                        bill[x5ai]=x5av
                        cur.execute("INSERT INTO sales (ItemName,ItemPrice,Date) VALUES (?,?,datetime('now','localtime'))",(x5a,x5av) )
                        conn.commit()


                    #milk--->140   
                    elif x5=="b": 
                        x5bi=x5b+"----"
                        bill[x5bi]=x5bv
                        cur.execute("INSERT INTO sales (ItemName,ItemPrice,Date) VALUES (?,?,datetime('now','localtime'))",(x5b,x5bv) )
                        conn.commit()



            elif x==6:
                #WINE(RED,WHITE):PER_GLASS----->Rs(400,500)
                print(f"""\n--------------WINE per GLASS----------\na.Red------>Rs.{x6av}\nb.White---->Rs.{x6bv}\n""")
                try:
                    x6=input("Enter  Your Choice:")
                    if x6 not in "ab":
                        raise
                except:
                    print("\nPlease Choose a or b ")
                    continue
                else:
                    #Red---->Rs.400 
                    if x6=="a":
                        x6ai=x6a+"-------"
                        bill[x6ai]=x6av
                        cur.execute("INSERT INTO sales (ItemName,ItemPrice,Date) VALUES (?,?,datetime('now','localtime'))",(x6a,x6av) )
                        conn.commit()


                    #White--->Rs.500   
                    elif x6=="b": 
                        x6bi=x6b+"-----"
                        bill[x6bi]=x6bv  
                        cur.execute("INSERT INTO sales (ItemName,ItemPrice,Date) VALUES (?,?,datetime('now','localtime'))",(x6b,x6bv) )
                        conn.commit()
                    #last ko             
            x12=input("\nDo You want to order other things\n press 1 for YES \n press ANYKEY for NO :")
            if x12 in "1":
                order()  


            z=False
        #INSERT AFTER CALLING THE MENu        
#        print("\nEnjoy Your Food\nTHANK YOU!!!")   
    conn.close()

# %% [markdown]
# # FOR ROOMS

# %% [markdown]
# ## For Filling ROOMS

# %%
def fill_room(roomType,available,name,pn):
    if roomType==1:
        for i in available:
            print(i,end=" ")
        while True:    
            choice=int(input("\nCHOOSE BETWEEN THE FOLLOWING ROOMS:"))
            try:
                if choice not in available:
                    raise
            except:
                print("\tPLEASE!!!\nENTER THE VALID CHOICES ONLY")
                continue
            else:    
                conn = sqlite3.connect("StdRoom.db")
                cur=conn.cursor()
                cur.execute("UPDATE StdRoom SET Name=? ,PhoneNo=? ,Filled=1 WHERE RoomNo=?",(name,pn,choice))
                conn.commit()
                bill["StdRoom--------"]=1500
                print(f'ROOM RENTED {emoji.emojize(":grinning_face_with_big_eyes:")}')
                conn.close()
                break
    elif roomType==2:
        for i in available:
            print(i,end=" ")
        while True:    
            choice=int(input("CHOOSE BETWEEN THE FOLLOWING ROOMS:"))
            try:
                if choice not in available:
                    raise
            except:
                print("\tPLEASE!!!\nENTER THE VALID CHOICES ONLY")
                continue
            else:   
                conn = sqlite3.connect("DelRoom.db")
                cur = conn.cursor()
                cur.execute("UPDATE DelRoom SET Name=? ,PhoneNo=? ,Filled=1 WHERE RoomNo=?",(name,pn,choice))
                conn.commit()
                bill["DelRoom--------"]=2000
                print(f'ROOM RENTED {emoji.emojize(":grinning_face_with_big_eyes:")}')
                conn.close()
                break
                
                
    elif roomType==3:
        for i in available:
            print(i,end=" ")
        while True:    
            choice=int(input("CHOOSE BETWEEN THE FOLLOWING ROOMS:"))
            try:
                if choice not in available:
                    raise
            except:
                print("\tPLEASE!!!\nENTER THE VALID CHOICES ONLY")
                continue
            else:  
                conn = sqlite3.connect("SDelRoom.db")
                cur=conn.cursor()
                cur.execute("UPDATE SDelRoom SET Name=? ,PhoneNo=? ,Filled=1 WHERE RoomNo=?",(name,pn,choice))
                conn.commit()
                bill["SDelRoom-------"]=3500
                print(f'ROOM RENTED {emoji.emojize(":grinning_face_with_big_eyes:")}')
                conn.close()
                break

# %% [markdown]
# ## Room Types

# %%
def stdRoom(name,pn):
    conn = sqlite3.connect("StdRoom.db")
    cur = conn.cursor()
    n=[i for i, in cur.execute("SELECT RoomNo FROM StdRoom  WHERE Filled=0")]
    if(n != []):
        print("STANDARD ROOM IS AVAILABLE")
        fill_room(1,n,name,pn)
    else:
        print("STANDARD ROOM IS FULL")
    conn.close()    
        
def delRoom(name,pn):
    conn = sqlite3.connect("DelRoom.db")
    cur = conn.cursor()
    n=[i for i, in cur.execute("SELECT RoomNo FROM DelRoom  WHERE Filled=0")]
    #available room ko list nikalxa one line looping use gara ra
    if(n!= []):
        print("DELUXE ROOM IS AVAILABLE")
        fill_room(2,n,name,pn)
    else:
        print("DELUXE ROOM IS FULL")
    conn.close()
    
    
def sDelRoom(name,pn):
    conn = sqlite3.connect("SDelRoom.db")
    cur = conn.cursor()
    n=[i for i, in cur.execute("SELECT RoomNo FROM SDelRoom  WHERE Filled=0")]
    if(n!= []):
        print("SUPER DELUXE ROOM IS AVAILABLE")
        fill_room(3,n,name,pn)
    else:
        print("SUPER DELUXE ROOM IS FULL")
    conn.close()

# %% [markdown]
# ## Select Rooms

# %%
def roomSelect(name,pn):
    print("""
    \t\tWELCOME!!!\n
    WE PROVIDE THE FOLLOWING ROOMS\n
    1.Standard_Room---------->Rs.1500
    2.Deluxe_Room------------>Rs.2000
    3.Super_Deluxe_Room------>Rs.3500""")
    try:
        choice=int(input("ENTER YOUR CHOICE:"))
        if choice not in [1,2,3]:
            raise
    except:
        print("\tPLEASE!!!\nCHOOSE THE PROVIDED OPTIONS ONLY ")
        roomSelect(name,pn)
    else:
        if choice==1:
            stdRoom(name,pn)
        elif choice==2:
            delRoom(name,pn)
        elif choice==3:
            sDelRoom(name,pn)

# %% [markdown]
# # FEATURES

# %% [markdown]
# # 1)MENU

# %%
def menu():
    print("""\t\t\tCHOSEN TO Order Food\n\n""")
#     choose=int(input("Enter Ur Choice:"))
#     try:
#         if choose not in range(1,3):
#             raise
#     except:
#         print("Enter the Choice correctly")
#     else:
#         if choose==1:
#             change_record()
#     if choose==2:
    order()

# %% [markdown]
# # 2)SEE SALES RECORD

# %%
def seeSalesRecord():
    con = sqlite3.connect("soldDetails.db")
    cur=con.cursor()
    y,m,d=input("Enter the year month and day from which you want to see the week data ").split()
    x=f"{y}-{m}-{d}"
    x2=f"{y}-{m}-{str(int(d)+7)}"
    for row in cur.execute(f"SELECT * FROM sales WHERE Date BETWEEN ? AND ?",(x,x2)):
        if(row[1]=="Chicken Chowmin"):
            print(f"ItemNo.={row[0]} "+ f"\t ItemName={row[1]}"+"\t"+ f"ItemPrice={row[2]}\t\t Date={row[3]}  ")
        else:
            print(f"ItemNo.={row[0]} "+ f"\t ItemName={row[1]}"+"\t"*2+ f"ItemPrice={row[2]}\t\t Date={row[3]}  ")
    con.close()

# %%
def sales():
    con = sqlite3.connect("soldDetails.db")
    cur=con.cursor()
    for row in cur.execute("SELECT * FROM sales"):
        if(row[1]=="Chicken Chowmin"):
            print(f"ItemNo.={row[0]} "+ f"\t ItemName={row[1]}"+"\t"+ f"ItemPrice={row[2]}\t\t Date={row[3]}  ")
        else:
            print(f"ItemNo.={row[0]} "+ f"\t ItemName={row[1]}"+"\t"*2+ f"ItemPrice={row[2]}\t\t Date={row[3]}  ")
    con.close()

# %% [markdown]
# # 3)CHANGE RECORDS

# %%
def change_record():
    #changed here at 8:19 12/21/2019
    global x1av,x1bv,x1cv,x2av,x2bv,x2cv,x3av,x3bv,x3cv,x4av,x4bv,x4cv,x5av,x5bv,x6av,x6bv
    conn = sqlite3.connect("menu.db")
    cur = conn.cursor()
    x= g.getpass('Password:')
    if x!=password:
        print("You Dont Have the access")
        pass
    else:
        z=True
        global x1av,x1bv,x1cv,x2av,x2bv,x2cv,x3av,x3bv,x3cv,x4av,x4bv,x4cv,x5av,x5bv,x6av,x6bv
        print("\n"*10)
        print(f"""\t    1.MEAL(VEG,CHICKEN,MUTTON)------>Rs({x1av},{x1bv},{x1cv})\n
            2.MO:MO(VEG,CHICKEN,BUFF)------->Rs({x2av},{x2bv},{x2cv})\n
            3.CHOWMIN(VEG,CHICKEN,BUFF)----->Rs({x3av},{x3bv},{x3cv})\n
            4.TEA(BLACK,MILK,GREEN)--------->Rs({x4av},{x4bv},{x4cv})\n
            5.COFFEE(BLACK,MILK)------------>Rs({x5av},{x5bv})\n
            6.WINE(RED,WHITE):PER_GLASS----->Rs({x6av},{x6bv})""")
        try:
            x=int(input("Enter Your Choice:"))
            if x not in range(1,7):#(1 ,2,3,4,5,6)
                raise
        except:
            print("\nPlease choose 1-6")
            change_record()
        else:
            while z:
                if x==1:
                    #MEAL
                    print(f"""\n-------------MEAL----------\na.Veg-------->Rs.{x1av} \nb.Chicken---->Rs.{x1bv}\nc.Mutton----->Rs.{x1cv}\n""")
                    try:
                        x1=input("\nEnter  Your Choice:")
                        if x1 not in "abc":
                            raise
                    except:
                        print("\nPlease Choose a ,b or c")
                        continue
                    else:
                        #VEG--->200
                        if x1=="a":
                            while True:
                                try:
                                    x1av=int(input("Enter The New Price:"))
                                    cur.execute("UPDATE MENU_MODEL SET itemPrice=? WHERE menuItem=?",(x1av,x1a))
                                    conn.commit()

                                except ValueError:
                                    #auta string input dida auxa error
                                    #arko database close vako vaya or open vai rakhda
                                    print("Enter A Valid Value In Number")
                                    continue
                                except:
                                    print("Is the databse ok ???")
                                    print("RECONNECTING TO THE DATABSE...")
                                    conn.close()
                                    conn = sqlite3.connect("menu.db")
                                    cur = conn.cursor()
                                else:
                                    break
                                
                                


                        #Chicken---> 250   
                        elif x1=="b": 
                            while True:
                                try:
                                    x1bv=int(input("Enter The New Price:"))
                                    cur.execute("UPDATE MENU_MODEL SET itemPrice=? WHERE menuItem=?",(x1bv,x1b))
                                    conn.commit()

                                except ValueError:
                                    #auta string input dida auxa error
                                    #arko database close vako vaya or open vai rakhda
                                    print("Enter A Valid Value In Number")
                                    continue
                                except:
                                    print("Is the databse ok ???")
                                    print("RECONNECTING TO THE DATABSE...")
                                    conn.close()
                                    conn = sqlite3.connect("menu.db")
                                    cur = conn.cursor()
                                else:
                                    break


                        #Mutton-->300
                        elif x1=="c":
                            while True:
                                try:
                                    x1cv=int(input("Enter The New Price:"))
                                    cur.execute("UPDATE MENU_MODEL SET itemPrice=? WHERE menuItem=?",(x1cv,x1c))
                                    conn.commit()

                                except ValueError:
                                    #auta string input dida auxa error
                                    #arko database close vako vaya or open vai rakhda
                                    print("Enter A Valid Value In Number")
                                    continue
                                except:
                                    print("Is the databse ok ???")
                                    print("RECONNECTING TO THE DATABSE...")
                                    conn.close()
                                    conn = sqlite3.connect("menu.db")
                                    cur = conn.cursor()
                                else:
                                    break








                elif x==2:
                    #MO:MO(VEG,CHICKEN,BUFF)------->Rs(100,160,120)
                    print(f"\n-------------MO:MO----------\na.Veg-------->Rs.{x2av}\nb.Chicken---->Rs.{x2bv}\nc.Buff------->Rs.{x2cv}")
                    try:

                        x2=input("\nEnter  Your Choice:")
                        if x2 not in "abc":
                            raise
                    except:
                        print("\nPlease Choose a ,b or c")
                        continue
                    else:
                        #VEG--->100
                        if x2=="a":
                            while True:
                                try:
                                    x2av=int(input("Enter The New Price:"))
                                    cur.execute("UPDATE MENU_MODEL SET itemPrice=? WHERE menuItem=?",(x2av,x2a))
                                    conn.commit()

                                except ValueError:
                                    #auta string input dida auxa error
                                    #arko database close vako vaya or open vai rakhda
                                    print("Enter A Valid Value In Number")
                                    continue
                                except:
                                    print("Is the databse ok ???")
                                    print("RECONNECTING TO THE DATABSE...")
                                    conn.close()
                                    conn = sqlite3.connect("menu.db")
                                    cur = conn.cursor()
                                else:
                                    break


                        #Chicken--->160   
                        elif x2=="b": 
                            while True:
                                try:
                                    x2bv=int(input("Enter The New Price:"))
                                    cur.execute("UPDATE MENU_MODEL SET itemPrice=? WHERE menuItem=?",(x2bv,x2b))
                                    conn.commit()

                                except:
                                    #auta string input dida auxa error
                                    #arko database close vako vaya or open vai rakhda
                                    print("Enter A Valid Value In Number")
                                    continue
                                else:
                                    break

                        #buff--->120
                        elif x2=="c":
                            while True:
                                try:
                                    x2cv=int(input("Enter The New Price:"))
                                    cur.execute("UPDATE MENU_MODEL SET itemPrice=? WHERE menuItem=?",(x2cv,x2c))
                                    conn.commit()

                                except ValueError:
                                    #auta string input dida auxa error
                                    #arko database close vako vaya or open vai rakhda
                                    print("Enter A Valid Value In Number")
                                    continue
                                except:
                                    print("Is the databse ok ???")
                                    print("RECONNECTING TO THE DATABSE...")
                                    conn.close()
                                    conn = sqlite3.connect("menu.db")
                                    cur = conn.cursor()
                                else:
                                    break








                elif x==3:
                    #CHOWMIN(VEG,CHICKEN,BUFF)----->Rs(80,120,100)
                    print(f"\n------------CHOWMIN----------\na.Veg-------->Rs.{x3av}\nb.Chicken---->Rs.{x3bv}\nc.Buff------->Rs.{x3cv}\n")
                    try:

                        x3=input("\nEnter  Your Choice:")
                        if x3 not in "abc":
                            raise
                    except:
                        print("\nPlease Choose a ,b or c")
                        continue
                    else:
                        #VEG--->80
                        if x3=="a":
                            while True:
                                try:
                                    x3av=int(input("Enter The New Price:"))
                                    cur.execute("UPDATE MENU_MODEL SET itemPrice=? WHERE menuItem=?",(x3av,x3a))
                                    conn.commit()

                                except ValueError:
                                    #auta string input dida auxa error
                                    #arko database close vako vaya or open vai rakhda
                                    print("Enter A Valid Value In Number")
                                    continue
                                except:
                                    print("Is the databse ok ???")
                                    print("RECONNECTING TO THE DATABSE...")
                                    conn.close()
                                    conn = sqlite3.connect("menu.db")
                                    cur = conn.cursor()
                                else:
                                    break


                        #Chicken--->120   
                        elif x3=="b": 
                            while True:
                                try:
                                    x3bv=int(input("Enter The New Price:"))
                                    cur.execute("UPDATE MENU_MODEL SET itemPrice=? WHERE menuItem=?",(x3bv,x3b))
                                    conn.commit()

                                except ValueError:
                                    #auta string input dida auxa error
                                    #arko database close vako vaya or open vai rakhda
                                    print("Enter A Valid Value In Number")
                                    continue
                                except:
                                    print("Is the databse ok ???")
                                    print("RECONNECTING TO THE DATABSE...")
                                    conn.close()
                                    conn = sqlite3.connect("menu.db")
                                    cur = conn.cursor()
                                else:
                                    break


                        #buff--->100
                        elif x3=="c":
                            while True:
                                try:
                                    x3cv=int(input("Enter The New Price:"))
                                    cur.execute("UPDATE MENU_MODEL SET itemPrice=? WHERE menuItem=?",(x3cv,x3c))
                                    conn.commit()

                                except ValueError:
                                    #auta string input dida auxa error
                                    #arko database close vako vaya or open vai rakhda
                                    print("Enter A Valid Value In Number")
                                    continue
                                except:
                                    print("Is the databse ok ???")
                                    print("RECONNECTING TO THE DATABSE...")
                                    conn.close()
                                    conn = sqlite3.connect("menu.db")
                                    cur = conn.cursor()
                                else:
                                    break




                elif x==4:
                    #TEA(BLACK,MILK,GREEN)--------->Rs(40,60,100)
                    print(f"\n--------------TEA----------\na.Black---->Rs.{x4av}\nb.Milk----->Rs.{x4bv}\nc.Green---->Rs.{x4cv}\n")
                    try:
                        x4=input("\nEnter  Your Choice:")
                        if x4 not in "abc":
                            raise
                    except:
                        print("\nPlease Choose a ,b or c")
                        continue
                    else:
                        #Black--->40
                        if x4=="a":
                            while True:
                                try:
                                    x4av=int(input("Enter The New Price:"))
                                    cur.execute("UPDATE MENU_MODEL SET itemPrice=? WHERE menuItem=?",(x4av,x4a))
                                    conn.commit()

                                except ValueError:
                                    #auta string input dida auxa error
                                    #arko database close vako vaya or open vai rakhda
                                    print("Enter A Valid Value In Number")
                                    continue
                                except:
                                    print("Is the databse ok ???")
                                    print("RECONNECTING TO THE DATABSE...")
                                    conn.close()
                                    conn = sqlite3.connect("menu.db")
                                    cur = conn.cursor()
                                else:
                                    break


                        #milk--->60   
                        elif x4=="b": 
                            while True:
                                try:
                                    x4bv=int(input("Enter The New Price:"))
                                    cur.execute("UPDATE MENU_MODEL SET itemPrice=? WHERE menuItem=?",(x4bv,x4b))
                                    conn.commit()

                                except ValueError:
                                    #auta string input dida auxa error
                                    #arko database close vako vaya or open vai rakhda
                                    print("Enter A Valid Value In Number")
                                    continue
                                except:
                                    print("Is the databse ok ???")
                                    print("RECONNECTING TO THE DATABSE...")
                                    conn.close()
                                    conn = sqlite3.connect("menu.db")
                                    cur = conn.cursor()
                                else:
                                    break



                        #green--->100
                        elif x4=="c":
                            while True:
                                try:
                                    x4cv=int(input("Enter The New Price:"))
                                    cur.execute("UPDATE MENU_MODEL SET itemPrice=? WHERE menuItem=?",(x4cv,x4c))
                                    conn.commit()

                                except ValueError:
                                    #auta string input dida auxa error
                                    #arko database close vako vaya or open vai rakhda
                                    print("Enter A Valid Value In Number")
                                    continue
                                except:
                                    print("Is the databse ok ???")
                                    print("RECONNECTING TO THE DATABSE...")
                                    conn.close()
                                    conn = sqlite3.connect("menu.db")
                                    cur = conn.cursor()
                                else:
                                    break




                elif x==5:
                    #COFFEE(BLACK,MILK)------------>Rs(100,140)
                    print(f"\n--------------COFFEE----------\na.Black---->Rs.{x5av}\nb.Milk----->Rs.{x5bv}\n")
                    try:
                        x5=input("Enter  Your Choice:")
                        if x5 not in "ab":
                            raise
                    except:
                        print("Please Choose a or b ")
                        continue
                    else:
                        #Black--->100
                        if x5=="a":
                            while True:
                                try:
                                    x5av=int(input("Enter The New Price:"))
                                    cur.execute("UPDATE MENU_MODEL SET itemPrice=? WHERE menuItem=?",(x5av,x5a))
                                    conn.commit()

                                except ValueError:
                                    #auta string input dida auxa error
                                    #arko database close vako vaya or open vai rakhda
                                    print("Enter A Valid Value In Number")
                                    continue
                                except:
                                    print("Is the databse ok ???")
                                    print("RECONNECTING TO THE DATABSE...")
                                    conn.close()
                                    conn = sqlite3.connect("menu.db")
                                    cur = conn.cursor()
                                else:
                                    break




                        #milk--->140   
                        elif x5=="b": 
                            while True:
                                try:
                                    x5bv=int(input("Enter The New Price:"))
                                    cur.execute("UPDATE MENU_MODEL SET itemPrice=? WHERE menuItem=?",(x5bv,x5b))
                                    conn.commit()

                                except ValueError:
                                    #auta string input dida auxa error
                                    #arko database close vako vaya or open vai rakhda
                                    print("Enter A Valid Value In Number")
                                    continue
                                except:
                                    print("Is the databse ok ???")
                                    print("RECONNECTING TO THE DATABSE...")
                                    conn.close()
                                    conn = sqlite3.connect("menu.db")
                                    cur = conn.cursor()
                                else:
                                    break



                elif x==6:
                    #WINE(RED,WHITE):PER_GLASS----->Rs(400,500)
                    print(f"""\n--------------WINE per GLASS----------\na.Red------>Rs.{x6av}\nb.White---->Rs.{x6bv}\n""")
                    try:
                        x6=input("Enter  Your Choice:")
                        if x6 not in "ab":
                            raise
                    except:
                        print("\nPlease Choose a or b ")
                        continue
                    else:
                        #Red---->Rs.400 
                        if x6=="a":
                            while True:
                                try:
                                    x6av=int(input("Enter The New Price:"))
                                    cur.execute("UPDATE MENU_MODEL SET itemPrice=? WHERE menuItem=?",(x6av,x6a))
                                    conn.commit()

                                except ValueError:
                                    #auta string input dida auxa error
                                    #arko database close vako vaya or open vai rakhda
                                    print("Enter A Valid Value In Number")
                                    continue
                                except:
                                    print("Is the databse ok ???")
                                    print("RECONNECTING TO THE DATABSE...")
                                    conn.close()
                                    conn = sqlite3.connect("menu.db")
                                    cur = conn.cursor()
                                else:
                                    break


                        #White--->Rs.500   
                        elif x6=="b": 
                            while True:
                                try:
                                    x6bv=int(input("Enter The New Price:"))
                                    cur.execute("UPDATE MENU_MODEL SET itemPrice=? WHERE menuItem=?",(x6bv,x6b))
                                    conn.commit()

                                except ValueError:
                                    #auta string input dida auxa error
                                    #arko database close vako vaya or open vai rakhda
                                    print("Enter A Valid Value In Number")
                                    continue
                                except:
                                    print("Is the databse ok ???")
                                    print("RECONNECTING TO THE DATABSE...")
                                    conn.close()
                                    conn = sqlite3.connect("menu.db")
                                    cur = conn.cursor()
                                else:
                                    break
                        #last ko             
                x12=input("\nDo You want to update other item prices\n press 1 for YES \n press ANYKEY for NO :")
                if x12 in "1":
                    change_record()  

                z=False
    conn.close()

# %% [markdown]
# # 4)FOOD_OR_ROOM

# %%
def room_or_food(name,pn):
    while True:
        try:
            x=input("Enter :\n1.For Renting A ROOM \n2.Food Related\n ")
            if x not in "12":
                raise
        except:
            print("Enter either 1 or 2\n")
        else:
            if x =="1":
                roomSelect(name,pn)
                break
            else:
                menu()
                print("\nEnjoy Your Food\nTHANK YOU!!!") 
                break
def show_bill(name,pn):
    
    while True:       
        try:        
            x1=input("Press 1 To Check Bill\nPress 2 To Enjoy The Stay\nPress 3 To Quit\n")  
            if x1 not in "123":
                raise
        except:
            print("Enter either 1 or  2\n")
        else:    
            if x1=="1":
                billing(name,pn)
            elif x1=="2":
                brain()
            elif x1=="3":
                if clear:
                    exit(0)
                else:
                    billing(name,pn)
                    exit(0)

# %% [markdown]
# # 5) BILLING

# %%
def billing(name,pn):
    price=0
    global clear
    #price=0#comment this
    z=0
    print("\n"*10)
    for x in bill.values():
        z=z+x
    print("\t\t\tTotal Bill={}".format(z))
    
    paid=int(input("\n\nEnter the amount of money paid by the customer:"))
    if paid<z:
        paid_less(paid,z)
        print("\n"*5)
        print(f"BILL FOR {name}    PHONE NUMBER {pn}")
        print("_"*41)
        for x,y in bill.items():
            print("|"+" "+x+"---------->"+str(y)+"\t\t|")
            price=price+y
        print("|"+"-"*39+"|")
        print("|"+"TOTAL"+ "-"*21+">"+"Rs."+str(price)+"\t"+"|")
        print("|"+"-"*39+"|")
        print("*"*19+"PAID"+"*"*18)
        
    else:
        print("\n"*5)
        print(f"BILL FOR {name}    PHONE NUMBER {pn}")
        print("_"*41)
        for x,y in bill.items():
            print("|"+" "+x+"---------->"+str(y)+"\t\t|")
            price=price+y
        print("|"+"-"*39+"|")
        print("|"+"TOTAL"+ "-"*19+">"+"Rs."+str(price)+"\t"+"|")
        print("|"+"PAID"+"-"*20+">"+"Rs."+str(paid)+"\t"+"|")
        print("|"+"RETURN"+"-"*18+">"+"Rs."+str(paid_more(paid,price))+"\t\t"+"|")
        print("|"+"-"*39+"|")
        print("*"*19+"PAID"+"*"*18)
    clear = True  
    
def paid_more(paid,price):
    ret=paid- price
    return ret
    

def paid_less(paid,price):
    #surma bill clear na garna la pakkai ni pachi tip didaina
    needed=price-paid
    print(f"You Need Rs.{needed} more to clear your bill\n")
    try:
        now=int(input("\n\tPlease! pay the remanining cash:"))
        if type(now) != type(1):
            print("\n\t\tEnter money in digits")
            raise
        if now>needed:
            print("\n\tPlease enter the needed amount only not more than that")
            raise
    except:
        paid_less(paid,price)
        
    else:
        needed=needed-now
        if needed==0:
            print("\nTHANK YOU FOR YOUR SERVICE!")
            return True
        else:
            paid=paid+now
            paid_less(paid,price)

# %% [markdown]
# # MAIN BRAIN OF THE PROGRAM

# %%
def administrator(name,pn):
    if name in admin and pn in admin.values():
        print("WELCOME BACK SIR!\n\n")
        f=int(input("""What Would You Like To Do Today?
            1.Change 
            2.Enjoy\n
            3.Quit\n"""))
        if f in list(range(1,4)):
            if f == 1 :
                print("Selected To Change Features\n")
                while True:
                    sel = input("""Enter
                                1.To Change Record 
                                2.To See Overall Sales
                                3.To See Manual Sales\n""")
                    if sel=="1":
                        change_record()
                    elif sel=="2":
                        sales()
                    elif sel=="3":
                        seeSalesRecord()
                    x=input("Anything Else ADMIN Y or N:").capitalize()
                    if x=="N":
                        print("\nMOVING TO USING HOTEL FACILITY\n\n")
                        break
                        
                
                
            elif f ==2:
                print("\nSelected To Enjoy The Hotel Facility\n\n")
            elif f==3:
                exit(0)

# %%
def brain():
    room_or_food(nam,p)
    while True:
        try:
            print("""
            1.For Yes
            2.For No
            """)
            x=int(input("AnyThing ELSE?"))
            if x not in list(range(1,3)):
                raise 
        except:
            print("Please Select The Appropriate option only!!!")
        else:
            if x==1:
                brain()
            elif x==2:
                show_bill(nam,p)
                print(f'\n\nTHANKS FOR USING OUR FACILITIES{emoji.emojize(":grinning_face_with_big_eyes:")} ')
                break

# %%
import emoji
import getpass as g
#here is the limitation 1 process at a time matra vayo 
nam,p=registration()
administrator(nam,int(p))
brain()
# Out:
# Enter Your Name:Shrish
# Enter Your Phone Number:9846856033
#
#
#
# WELCOME BACK SIR!
#
#
# What Would You Like To Do Today?
#             1.Change
#             2.Enjoy
#
#             3.Quit
# 1
# Selected To Change Features
#
# Enter
#                                 1.To Change Record
#                                 2.To See Overall Sales
#                                 3.To See Manual Sales
# 3
# Enter the year month and day from which you want to see the week data 2017 05 02
# Anything Else ADMIN Y or N:n
#
# MOVING TO USING HOTEL FACILITY
#
#
# Enter :
# 1.For Renting A ROOM
# 2.Food Related
#  2
# 			CHOSEN TO Order Food
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	1.MEAL(VEG,CHICKEN,MUTTON)------>Rs(200,250,300)
#
#         2.MO:MO(VEG,CHICKEN,BUFF)------->Rs(100,160,120)
#
#         3.CHOWMIN(VEG,CHICKEN,BUFF)----->Rs(80,120,100)
#
#         4.TEA(BLACK,MILK,GREEN)--------->Rs(40,60,100)
#
#         5.COFFEE(BLACK,MILK)------------>Rs(100,140)
#
#         6.WINE(RED,WHITE):PER_GLASS----->Rs(400,500)
# Enter Your Choice:1
#
# -------------MEAL----------
# a.Veg-------->Rs.200
# b.Chicken---->Rs.250
# c.Mutton----->Rs.300
#
#
# Enter  Your Choice:b
#
# Do You want to order other things
#  press 1 for YES
#  press ANYKEY for NO :1
#
#
#
#
#
#
#
#
#
#
#
# 	1.MEAL(VEG,CHICKEN,MUTTON)------>Rs(200,250,300)
#
#         2.MO:MO(VEG,CHICKEN,BUFF)------->Rs(100,160,120)
#
#         3.CHOWMIN(VEG,CHICKEN,BUFF)----->Rs(80,120,100)
#
#         4.TEA(BLACK,MILK,GREEN)--------->Rs(40,60,100)
#
#         5.COFFEE(BLACK,MILK)------------>Rs(100,140)
#
#         6.WINE(RED,WHITE):PER_GLASS----->Rs(400,500)
# Enter Your Choice:6
#
# --------------WINE per GLASS----------
# a.Red------>Rs.400
# b.White---->Rs.500
#
# Enter  Your Choice:b
#
# Do You want to order other things
#  press 1 for YES
#  press ANYKEY for NO :2
#
# Enjoy Your Food
# THANK YOU!!!
#
#             1.For Yes
#             2.For No
#
# AnyThing ELSE?2
# Press 1 To Check Bill
# Press 2 To Enjoy The Stay
# Press 3 To Quit
# 3
#
#
#
#
#
#
#
#
#
#
#
# 			Total Bill=750
#
#
# Enter the amount of money paid by the customer:750
#
#
#
#
#
#
# BILL FOR Shrish    PHONE NUMBER 9846856033
# _________________________________________
# | Chicken Meal------------->250		|
# | White Wine--------------->500		|
# |---------------------------------------|
# |TOTAL------------------->Rs.750	|
# |PAID-------------------->Rs.750	|
# |RETURN------------------>Rs.0		|
# |---------------------------------------|
# *******************PAID******************
# Press 1 To Check Bill
# Press 2 To Enjoy The Stay
# Press 3 To Quit
# 3
# Press 1 To Check Bill
# Press 2 To Enjoy The Stay
# Press 3 To Quit
# 3
# Press 1 To Check Bill
# Press 2 To Enjoy The Stay
# Press 3 To Quit
# 3

# %%
# pip install emoji

# %%
# pip install sqlite3
